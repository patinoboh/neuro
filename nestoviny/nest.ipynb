# %%
import nest
# Out:
# nest: python package requires root access
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /mnt/disk/patrik/neuro/.venv_neuro/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3587: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
